# %% [markdown]
# # BN-LTE MNI Brain Visualization Notebook
#
# This notebook is intentionally separate from the main validation notebook. It creates non-surface visualizations in the style of neuroimaging paper figure panels: MNI axial heatmaps, glass-brain marker views, a regional structural scaffold, and a compact montage.
#
# Important interpretation guardrail: these are regional DK/aparc summaries projected to approximate MNI coordinates with Gaussian kernels. They are useful anatomical visualizations of the model outputs, not voxelwise PET statistical maps.

# %% [markdown]
# ## Figure 1. MNI Axial Progression Heatmaps

# %% [markdown]
# ![fig1_mni_axial_progression_montage](outputs/mni_brain_visualization/figures/fig1_mni_axial_progression_montage.png)

# %% [markdown]
# ## Figure 2. MNI Axial Prediction-Error Heatmaps

# %% [markdown]
# ![fig2_mni_axial_prediction_error_montage](outputs/mni_brain_visualization/figures/fig2_mni_axial_prediction_error_montage.png)

# %% [markdown]
# ## Figure 3. MNI Axial BN-LTE Advantage Heatmaps

# %% [markdown]
# ![fig3_mni_axial_bnlte_advantage_montage](outputs/mni_brain_visualization/figures/fig3_mni_axial_bnlte_advantage_montage.png)

# %% [markdown]
# ## Figure 4. Glass-Brain Marker Heatmaps

# %% [markdown]
# ![fig4_mni_glass_brain_marker_panels](outputs/mni_brain_visualization/figures/fig4_mni_glass_brain_marker_panels.png)

# %% [markdown]
# ## Figure 5. Network-Aware Brain Visualization

# %% [markdown]
# ![fig5_mni_connectome_progression_overlay](outputs/mni_brain_visualization/figures/fig5_mni_connectome_progression_overlay.png)

# %% [markdown]
# ## Figure 6. Paper-Style Summary Montage

# %% [markdown]
# ![fig6_mni_paper_style_summary_montage](outputs/mni_brain_visualization/figures/fig6_mni_paper_style_summary_montage.png)

# %% [markdown]
# ## Regional MNI Value Table

# %% [markdown]
# [Open CSV: `mni_region_values`](outputs/mni_brain_visualization/mni_region_values.csv)
#
# **mni_region_values**: 10 rows x 24 columns
#
# <div style="max-height:650px; overflow:auto; border:1px solid #ddd; padding:8px">
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>region</th>
#       <th>short_region</th>
#       <th>mni_x</th>
#       <th>mni_y</th>
#       <th>mni_z</th>
#       <th>baseline_mean_suvr</th>
#       <th>empirical_followup_suvr</th>
#       <th>empirical_delta_suvr</th>
#       <th>bnlte_advantage_vs_mean_competitor</th>
#       <th>bnlte_followup_suvr</th>
#       <th>bnlte_delta_suvr</th>
#       <th>bnlte_abs_error_suvr</th>
#       <th>esm_followup_suvr</th>
#       <th>esm_delta_suvr</th>
#       <th>esm_abs_error_suvr</th>
#       <th>sir_followup_suvr</th>
#       <th>sir_delta_suvr</th>
#       <th>sir_abs_error_suvr</th>
#       <th>ndm_followup_suvr</th>
#       <th>ndm_delta_suvr</th>
#       <th>ndm_abs_error_suvr</th>
#       <th>persistence_followup_suvr</th>
#       <th>persistence_delta_suvr</th>
#       <th>persistence_abs_error_suvr</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>L_entorhinal</td>
#       <td>L-Ent</td>
#       <td>-24.0</td>
#       <td>-14.0</td>
#       <td>-28.0</td>
#       <td>1.223099</td>
#       <td>1.262039</td>
#       <td>0.038941</td>
#       <td>0.052727</td>
#       <td>1.267584</td>
#       <td>0.044486</td>
#       <td>0.005545</td>
#       <td>1.234760</td>
#       <td>0.011661</td>
#       <td>0.027280</td>
#       <td>1.234752</td>
#       <td>0.011654</td>
#       <td>0.027287</td>
#       <td>1.122459</td>
#       <td>-0.100640</td>
#       <td>0.139580</td>
#       <td>0.0</td>
#       <td>0.069500</td>
#     </tr>
#     <tr>
#       <td>L_middletemporal</td>
#       <td>L-MT</td>
#       <td>-58.0</td>
#       <td>-44.0</td>
#       <td>0.0</td>
#       <td>1.244987</td>
#       <td>1.286388</td>
#       <td>0.041401</td>
#       <td>0.052975</td>
#       <td>1.294097</td>
#       <td>0.049110</td>
#       <td>0.007709</td>
#       <td>1.267691</td>
#       <td>0.022705</td>
#       <td>0.018697</td>
#       <td>1.267677</td>
#       <td>0.022690</td>
#       <td>0.018711</td>
#       <td>1.122459</td>
#       <td>-0.122528</td>
#       <td>0.163929</td>
#       <td>1.244987</td>
#       <td>0.0</td>
#       <td>0.041401</td>
#     </tr>
#     <tr>
#       <td>R_middletemporal</td>
#       <td>R-MT</td>
#       <td>58.0</td>
#       <td>-44.0</td>
#       <td>0.0</td>
#       <td>1.232658</td>
#       <td>1.285651</td>
#       <td>0.052993</td>
#       <td>0.062803</td>
#       <td>1.279567</td>
#       <td>0.046909</td>
#       <td>0.006084</td>
#       <td>1.255976</td>
#       <td>0.023319</td>
#       <td>0.029675</td>
#       <td>1.255962</td>
#       <td>0.023304</td>
#       <td>0.029689</td>
#       <td>1.122459</td>
#       <td>-0.110199</td>
#       <td>0.163192</td>
#       <td>1.232658</td>
#       <td>0.0</td>
#       <td>0.052993</td>
#     </tr>
#     <tr>
#       <td>L_inferiorparietal</td>
#       <td>L-IP</td>
#       <td>-44.0</td>
#       <td>-64.0</td>
#       <td>38.0</td>
#       <td>1.192441</td>
#       <td>1.231118</td>
#       <td>0.038678</td>
#       <td>0.035952</td>
#       <td>1.223437</td>
#       <td>0.030996</td>
#       <td>0.007681</td>
#       <td>1.217529</td>
#       <td>0.025088</td>
#       <td>0.013590</td>
#       <td>1.217513</td>
#       <td>0.025072</td>
#       <td>0.013606</td>
#       <td>1.122459</td>
#       <td>-0.069982</td>
#       <td>0.108659</td>
#       <td>1.192441</td>
#       <td>0.0</td>
#       <td>0.038678</td>
#     </tr>
#     <tr>
#       <td>R_inferiorparietal</td>
#       <td>R-IP</td>
#       <td>44.0</td>
#       <td>-64.0</td>
#       <td>38.0</td>
#       <td>1.178487</td>
#       <td>1.214789</td>
#       <td>0.036303</td>
#       <td>0.031346</td>
#       <td>1.208621</td>
#       <td>0.030134</td>
#       <td>0.006169</td>
#       <td>1.204086</td>
#       <td>0.025599</td>
#       <td>0.010704</td>
#       <td>1.204070</td>
#       <td>0.025583</td>
#       <td>0.010720</td>
#       <td>1.122459</td>
#       <td>-0.056028</td>
#       <td>0.092330</td>
#       <td>1.178487</td>
#       <td>0.0</td>
#       <td>0.036303</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# ## Metrics

# %% [markdown]
# ```json
# {
#   "bnlte_delta_spearman_vs_empirical": 0.6121212121212121,
#   "bnlte_group_followup_mae": 0.007913575305688236,
#   "esm_group_followup_mae": 0.025365651535025548,
#   "ndm_group_followup_mae": 0.15954750386864447,
#   "persistence_group_followup_mae": 0.04517302631578901,
#   "sir_group_followup_mae": 0.02537796365619065
# }
# ```

# %% [markdown]
# ## Guardrails

# %% [markdown]
# - These figures are visualization transforms of regional model outputs, not independently estimated voxelwise tau maps.
# - Gaussian MNI kernels use fixed approximate centroids so visual hot spots should be interpreted at the regional level.
# - Model comparison claims should use the numeric validation tables; these figures are anatomical summaries of those outputs.
