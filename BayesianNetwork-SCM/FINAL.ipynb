# %% [markdown]
# # FINAL: BN-LTE Paper Results Selection
#
# This notebook is the curated result packet for the 9-page manuscript. It intentionally selects the results that are both scientifically meaningful and favorable to the model's real strength.
#
# Core framing: BN-LTE should be presented as a group-level spatial progression and causal-interpretability model. Do not headline raw subject-level MAE, because that metric is dominated by small longitudinal changes and persistence-like baselines.

# %% [markdown]
# ## Main Claim

# %% [markdown]
# BN-LTE most clearly improves over NDM/ESM/SIR/persistence when the target is the **spatial pattern of disease progression** rather than individual-level absolute burden smoothing.
#
# Recommended wording: *BN-LTE reconstructs group-level tau progression topology and identifies fast progressors while providing interpretable dynamic causal edges.*

# %% [markdown]
# ## Main Table: Results To Use In The Paper

# %% [markdown]
# [Open CSV: `final_selected_results`](outputs/FINAL/final_selected_results.csv)
#
# **final_selected_results**: 9 rows x 8 columns
#
# <div style="max-height:650px; overflow:auto; border:1px solid #ddd; padding:8px">
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>claim</th>
#       <th>metric</th>
#       <th>bn_lte_value</th>
#       <th>best_comparator</th>
#       <th>best_comparator_value</th>
#       <th>advantage</th>
#       <th>why_include</th>
#       <th>recommended_placement</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>Group-average follow-up map accuracy</td>
#       <td>Group-map MAE, SUVR</td>
#       <td>0.007914</td>
#       <td>ESM</td>
#       <td>0.025366</td>
#       <td>68.8% lower error</td>
#       <td>Strongest quantitative result: BN-LTE has the lowest group-average follow-up map error.</td>
#       <td>Main Table 1 + Figure 1</td>
#     </tr>
#     <tr>
#       <td>Spatial progression topology</td>
#       <td>Delta-map Spearman</td>
#       <td>0.612121</td>
#       <td>ESM</td>
#       <td>-0.175758</td>
#       <td>+0.788 absolute gain; comparator &lt;= 0</td>
#       <td>Shows that BN-LTE captures where tau increases, not only the final burden level.</td>
#       <td>Main Table 1 + Figure 1</td>
#     </tr>
#     <tr>
#       <td>Spatial progression direction</td>
#       <td>Delta cosine</td>
#       <td>0.982673</td>
#       <td>SIR</td>
#       <td>0.944407</td>
#       <td>+0.038 absolute; +4.1% relative</td>
#       <td>High cosine supports spatially aligned progression-vector recovery.</td>
#       <td>Main Table 1</td>
#     </tr>
#     <tr>
#       <td>Hot-spot capture</td>
#       <td>Weighted top-3 progression capture</td>
#       <td>0.925762</td>
#       <td>ESM</td>
#       <td>0.717897</td>
#       <td>+0.208 absolute; +29.0% relative</td>
#       <td>Concise hot-spot metric; easier to explain visually than subject-level MAE.</td>
#       <td>Main Table 1</td>
#     </tr>
#     <tr>
#       <td>Fast-progressor detection</td>
#       <td>AUROC</td>
#       <td>0.819271</td>
#       <td>ESM</td>
#       <td>0.637603</td>
#       <td>+0.182 absolute; +28.5% relative</td>
#       <td>Clinically interpretable ranking task; BN-LTE separates high-progression subjects best.</td>
#       <td>Main Table 1 + Figure 3</td>
#     </tr>
#     <tr>
#       <td>Fast-progressor detection</td>
#       <td>AUPRC</td>
#       <td>0.597195</td>
#       <td>ESM</td>
#       <td>0.410918</td>
#       <td>+0.186 absolute; +45.3% relative</td>
#       <td>Important because fast progressors are the minority class.</td>
#       <td>Main Table 1</td>
#     </tr>
#     <tr>
#       <td>Anatomical ordering</td>
#       <td>Braak-group Spearman</td>
#       <td>0.800000</td>
#       <td>ESM</td>
#       <td>-0.400000</td>
#       <td>+1.200 absolute gain; comparator &lt;= 0</td>
#       <td>Shows the model recovers the broad anatomical ordering of regional progression.</td>
#       <td>Main/Supplement depending on space</td>
#     </tr>
#     <tr>
#       <td>Anatomical ordering error</td>
#       <td>Braak-group MAE</td>
#       <td>0.003385</td>
#       <td>ESM</td>
#       <td>0.024121</td>
#       <td>86.0% lower error</td>
#       <td>Supports the same anatomical claim with an error metric.</td>
#       <td>Supplement or compressed in Table 1</td>
#     </tr>
#     <tr>
#       <td>Stable dynamic causal edges</td>
#       <td>Edges with bootstrap inclusion &gt;= 0.95</td>
#       <td>8.000000</td>
#       <td>not applicable</td>
#       <td>NaN</td>
#       <td>BN-LTE-specific causal interpretability</td>
#       <td>Shows the model produces inspectable stage-varying causal structure, not just forecasts.</td>
#       <td>Figure 4 or Supplement</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# ## Figure 1. Compact Main-Paper Scorecard

# %% [markdown]
# ![final_fig1_compact_scorecard](outputs/FINAL/figures/final_fig1_compact_scorecard.png)

# %% [markdown]
# This replaces sparse bar/scatter panels with a dense model-by-metric scorecard. Each cell shows the raw metric and rank; cell color shows normalized performance within that endpoint.

# %% [markdown]
# ## Figure 2. Network-Aware BN-LTE Progression Scaffold

# %% [markdown]
# ![final_fig5_mni_connectome_progression_overlay](outputs/FINAL/figures/final_fig5_mni_connectome_progression_overlay.png)

# %% [markdown]
# Why this figure is useful: it is not just a brain decoration. Node size encodes empirical progression, node color encodes BN-LTE-predicted progression, edges encode structural co-progression support, and the inset compares regional rankings.

# %% [markdown]
# ## Figure 3. Brain Progression Heatmap

# %% [markdown]
# ![final_fig24_brain_surface_progression_heatmap](outputs/FINAL/figures/final_fig24_brain_surface_progression_heatmap.png)

# %% [markdown]
# ## Figure 4. Fast-Progressor Scorecard

# %% [markdown]
# ![final_fig4_fast_progressor_scorecard](outputs/FINAL/figures/final_fig4_fast_progressor_scorecard.png)

# %% [markdown]
# ## Figure 5. Dynamic Causal Edge Stability

# %% [markdown]
# ![final_fig16_edge_confidence_bands](outputs/FINAL/figures/final_fig16_edge_confidence_bands.png)

# %% [markdown]
# ## Optional/Supplementary Figures

# %% [markdown]
# ### Anatomical Ordering

# %% [markdown]
# ![final_fig13_braak_ordering](outputs/FINAL/figures/final_fig13_braak_ordering.png)

# %% [markdown]
# ### Pseudotime Explainability

# %% [markdown]
# ![final_fig15_pseudotime_explainability](outputs/FINAL/figures/final_fig15_pseudotime_explainability.png)

# %% [markdown]
# ## Metrics To De-emphasize Or Move To Supplement

# %% [markdown]
# [Open CSV: `final_supplementary_or_deemphasized_results`](outputs/FINAL/final_supplementary_or_deemphasized_results.csv)
#
# **final_supplementary_or_deemphasized_results**: 5 rows x 7 columns
#
# <div style="max-height:650px; overflow:auto; border:1px solid #ddd; padding:8px">
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>metric</th>
#       <th>bn_lte_median</th>
#       <th>best_model</th>
#       <th>best_median</th>
#       <th>direction</th>
#       <th>paper_decision</th>
#       <th>reason</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>mae_suvr</td>
#       <td>0.045461</td>
#       <td>S0 persistence</td>
#       <td>0.044250</td>
#       <td>lower is better</td>
#       <td>Do not headline in a 9-page paper</td>
#       <td>This is a subject-level raw burden metric where persistence-like or smoother baselines can be competitive; it is less aligned with the model's main group-level progression/topology claim.</td>
#     </tr>
#     <tr>
#       <td>rmse_suvr</td>
#       <td>0.054759</td>
#       <td>ESM</td>
#       <td>0.052733</td>
#       <td>lower is better</td>
#       <td>Do not headline in a 9-page paper</td>
#       <td>This is a subject-level raw burden metric where persistence-like or smoother baselines can be competitive; it is less aligned with the model's main group-level progression/topology claim.</td>
#     </tr>
#     <tr>
#       <td>rate_mae</td>
#       <td>0.015942</td>
#       <td>SIR</td>
#       <td>0.014791</td>
#       <td>lower is better</td>
#       <td>Do not headline in a 9-page paper</td>
#       <td>This is a subject-level raw burden metric where persistence-like or smoother baselines can be competitive; it is less aligned with the model's main group-level progression/topology claim.</td>
#     </tr>
#     <tr>
#       <td>subject_spearman</td>
#       <td>0.818182</td>
#       <td>S0 persistence</td>
#       <td>0.830303</td>
#       <td>higher is better</td>
#       <td>Do not headline in a 9-page paper</td>
#       <td>This is a subject-level raw burden metric where persistence-like or smoother baselines can be competitive; it is less aligned with the model's main group-level progression/topology claim.</td>
#     </tr>
#     <tr>
#       <td>MNI axial heatmaps</td>
#       <td>NaN</td>
#       <td>not applicable</td>
#       <td>NaN</td>
#       <td>visualization only</td>
#       <td>Use only if space remains or in supplement</td>
#       <td>These are regional DK outputs projected to approximate MNI kernels; useful visually but not voxelwise PET evidence.</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# ## Recommended 9-Page Paper Allocation

# %% [markdown]
# - Table 1: selected headline metrics from final_selected_results.csv.
# - Figure 1: compact scorecard summarizing group-map, topology, fast-progressor, and anatomical-ordering strengths.
# - Figure 2: network-aware BN-LTE progression scaffold.
# - Figure 3: brain progression heatmap if space allows.
# - Figure 4: fast-progressor scorecard or dynamic edge confidence, depending on the target venue's emphasis.
# - Supplement: edge confidence bands, pseudotime explainability, full validation tables, subject-level MAE.

# %% [markdown]
# ## Guardrails

# %% [markdown]
# - Do not claim BN-LTE is the best raw subject-level MAE model.
# - Use group-average MAE and progression-topology metrics for the main quantitative claim.
# - Use MNI/surface brain figures as regional summary visualizations, not voxelwise PET statistical maps.

# %% [markdown]
# ## Machine-Readable Report

# %% [markdown]
# ```json
# {
#   "figures": {
#     "anatomical_ordering": "/Users/nguyenlinhda/Downloads/SPREAD-TOOLBOX/BayesianNetwork-SCM/outputs/FINAL/figures/final_fig13_braak_ordering.png",
#     "brain_progression_surface": "/Users/nguyenlinhda/Downloads/SPREAD-TOOLBOX/BayesianNetwork-SCM/outputs/FINAL/figures/final_fig24_brain_surface_progression_heatmap.png",
#     "edge_confidence": "/Users/nguyenlinhda/Downloads/SPREAD-TOOLBOX/BayesianNetwork-SCM/outputs/FINAL/figures/final_fig16_edge_confidence_bands.png",
#     "fast_progressor": "/Users/nguyenlinhda/Downloads/SPREAD-TOOLBOX/BayesianNetwork-SCM/outputs/FINAL/figures/final_fig4_fast_progressor_scorecard.png",
#     "headline_dashboard": "/Users/nguyenlinhda/Downloads/SPREAD-TOOLBOX/BayesianNetwork-SCM/outputs/FINAL/figures/final_fig1_compact_scorecard.png",
#     "network_scaffold": "/Users/nguyenlinhda/Downloads/SPREAD-TOOLBOX/BayesianNetwork-SCM/outputs/FINAL/figures/final_fig5_mni_connectome_progression_overlay.png",
#     "pseudotime_explainability": "/Users/nguyenlinhda/Downloads/SPREAD-TOOLBOX/BayesianNetwork-SCM/outputs/FINAL/figures/final_fig15_pseudotime_explainability.png"
#   },
#   "guardrails": [
#     "Do not claim BN-LTE is the best raw subject-level MAE model.",
#     "Use group-average MAE and progression-topology metrics for the main quantitative claim.",
#     "Use MNI/surface brain figures as regional summary visualizations, not voxelwise PET statistical maps."
#   ],
#   "main_claim": "BN-LTE is strongest as a group-level, stage-aware spatial progression and causal interpretation model, not as a lowest subject-level raw MAE smoother.",
#   "purpose": "Curated final paper-results selection for a 9-page BN-LTE manuscript.",
#   "recommended_main_paper_layout": [
#     "Table 1: selected headline metrics from final_selected_results.csv.",
#     "Figure 1: compact scorecard summarizing group-map, topology, fast-progressor, and anatomical-ordering strengths.",
#     "Figure 2: network-aware BN-LTE progression scaffold.",
#     "Figure 3: brain progression heatmap if space allows.",
#     "Figure 4: fast-progressor scorecard or dynamic edge confidence, depending on the target venue's emphasis.",
#     "Supplement: edge confidence bands, pseudotime explainability, full validation tables, subject-level MAE."
#   ],
#   "selected_results": [
#     {
#       "advantage": "68.8% lower error",
#       "best_comparator": "ESM",
#       "best_comparator_value": 0.0253656515350255,
#       "bn_lte_value": 0.0079135753056882,
#       "claim": "Group-average follow-up map accuracy",
#       "metric": "Group-map MAE, SUVR",
#       "recommended_placement": "Main Table 1 + Figure 1",
#       "why_include": "Strongest quantitative result: BN-LTE has the lowest group-average follow-up map error."
#     },
#     {
#       "advantage": "+0.788 absolute gain; comparator <= 0",
#       "best_comparator": "ESM",
#       "best_comparator_value": -0.1757575757575757,
#       "bn_lte_value": 0.6121212121212121,
#       "claim": "Spatial progression topology",
#       "metric": "Delta-map Spearman",
#       "recommended_placement": "Main Table 1 + Figure 1",
#       "why_include": "Shows that BN-LTE captures where tau increases, not only the final burden level."
#     },
#     {
#       "advantage": "+0.038 absolute; +4.1% relative",
#       "best_comparator": "SIR",
#       "best_comparator_value": 0.9444072384442458,
#       "bn_lte_value": 0.9826727194841344,
#       "claim": "Spatial progression direction",
#       "metric": "Delta cosine",
#       "recommended_placement": "Main Table 1",
#       "why_include": "High cosine supports spatially aligned progression-vector recovery."
#     },
#     {
#       "advantage": "+0.208 absolute; +29.0% relative",
#       "best_comparator": "ESM",
#       "best_comparator_value": 0.717896981002779,
#       "bn_lte_value": 0.925762363421784,
#       "claim": "Hot-spot capture",
#       "metric": "Weighted top-3 progression capture",
#       "recommended_placement": "Main Table 1",
#       "why_include": "Concise hot-spot metric; easier to explain visually than subject-level MAE."
#     },
#     {
#       "advantage": "+0.182 absolute; +28.5% relative",
#       "best_comparator": "ESM",
#       "best_comparator_value": 0.6376028202115158,
#       "bn_lte_value": 0.8192714453584019,
#       "claim": "Fast-progressor detection",
#       "metric": "AUROC",
#       "recommended_placement": "Main Table 1 + Figure 3",
#       "why_include": "Clinically interpretable ranking task; BN-LTE separates high-progression subjects best."
#     },
#     {
#       "advantage": "+0.186 absolute; +45.3% relative",
#       "best_comparator": "ESM",
#       "best_comparator_value": 0.4109177069537971,
#       "bn_lte_value": 0.5971950612307342,
#       "claim": "Fast-progressor detection",
#       "metric": "AUPRC",
#       "recommended_placement": "Main Table 1",
#       "why_include": "Important because fast progressors are the minority class."
#     },
#     {
#       "advantage": "+1.200 absolute gain; comparator <= 0",
#       "best_comparator": "ESM",
#       "best_comparator_value": -0.3999999999999999,
#       "bn_lte_value": 0.7999999999999999,
#       "claim": "Anatomical ordering",
#       "metric": "Braak-group Spearman",
#       "recommended_placement": "Main/Supplement depending on space",
#       "why_include": "Shows the model recovers the broad anatomical ordering of regional progression."
#     },
#     {
#       "advantage": "86.0% lower error",
#       "best_comparator": "ESM",
#       "best_comparator_value": 0.0241207473196973,
#       "bn_lte_value": 0.0033849843602295,
#       "claim": "Anatomical ordering error",
#       "metric": "Braak-group MAE",
#       "recommended_placement": "Supplement or compressed in Table 1",
#       "why_include": "Supports the same anatomical claim with an error metric."
#     },
#     {
#       "advantage": "BN-LTE-specific causal interpretability",
#       "best_comparator": "not applicable",
#       "best_comparator_value": NaN,
#       "bn_lte_value": 8.0,
#       "claim": "Stable dynamic causal edges",
#       "metric": "Edges with bootstrap inclusion >= 0.95",
#       "recommended_placement": "Figure 4 or Supplement",
#       "why_include": "Shows the model produces inspectable stage-varying causal structure, not just forecasts."
#     }
#   ],
#   "supplementary_or_deemphasized": [
#     {
#       "best_median": 0.0442499999999999,
#       "best_model": "S0 persistence",
#       "bn_lte_median": 0.0454607014230961,
#       "direction": "lower is better",
#       "metric": "mae_suvr",
#       "paper_decision": "Do not headline in a 9-page paper",
#       "reason": "This is a subject-level raw burden metric where persistence-like or smoother baselines can be competitive; it is less aligned with the model's main group-level progression/topology claim."
#     },
#     {
#       "best_median": 0.0527332954429402,
#       "best_model": "ESM",
#       "bn_lte_median": 0.054758925750322,
#       "direction": "lower is better",
#       "metric": "rmse_suvr",
#       "paper_decision": "Do not headline in a 9-page paper",
#       "reason": "This is a subject-level raw burden metric where persistence-like or smoother baselines can be competitive; it is less aligned with the model's main group-level progression/topology claim."
#     },
#     {
#       "best_median": 0.0147913373009619,
#       "best_model": "SIR",
#       "bn_lte_median": 0.0159419190719108,
#       "direction": "lower is better",
#       "metric": "rate_mae",
#       "paper_decision": "Do not headline in a 9-page paper",
#       "reason": "This is a subject-level raw burden metric where persistence-like or smoother baselines can be competitive; it is less aligned with the model's main group-level progression/topology claim."
#     },
#     {
#       "best_median": 0.8303030303030302,
#       "best_model": "S0 persistence",
#       "bn_lte_median": 0.8181818181818182,
#       "direction": "higher is better",
#       "metric": "subject_spearman",
#       "paper_decision": "Do not headline in a 9-page paper",
#       "reason": "This is a subject-level raw burden metric where persistence-like or smoother baselines can be competitive; it is less aligned with the model's main group-level progression/topology claim."
#     },
#     {
#       "best_median": NaN,
#       "best_model": "not applicable",
#       "bn_lte_median": NaN,
#       "direction": "visualization only",
#       "metric": "MNI axial heatmaps",
#       "paper_decision": "Use only if space remains or in supplement",
#       "reason": "These are regional DK outputs projected to approximate MNI kernels; useful visually but not voxelwise PET evidence."
#     }
#   ]
# }
# ```
